# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# #### **Abdulelah Burhan**

# %% [markdown]
# #### *I am interested in data science because its one of the sexiest job of the new world, I enjoy manipulating data and problem solve using ML models and other data science tools that we learned*

# %% [markdown]
# ### The following code Display my name as a pillar

# %%
a ="Abdulelah Burhan"
print(*a, sep = "\n")
# Out:
# A
# b
# d
# u
# l
# e
# l
# a
# h
#
# B
# u
# r
# h
# a
# n

# %% [markdown]
# * I
# * Like
# * Coding
#
# <img src="https://codingbootcamps.io/wp-content/uploads/m2.png" style="width:300px;height:300px;">
#
# [Exam cheat sheet](https://www.youtube.com/watch?v=dQw4w9WgXcQ&ab_channel=RickAstley)
